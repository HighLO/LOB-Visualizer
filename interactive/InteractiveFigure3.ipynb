// %%
#include "../../highlo/scripts/LiveLOB/GenerateLiveLOBPlot.cxx"

// %%
#include "../../highlo/scripts/LiveLOB/drawLOB3.C"

// %%
%jsroot on

// %%
std::string rootPath = "root://eosproject//eos/project/h/highlo/CMEROOT/messages/ZC";
std::string outputFileName = "file2.root";
TimeNS beginTime = timestampToNS("2015""08""12""1558""00""000");
TimeNS endTime   = timestampToNS("2015""08""12""1602""00""000");
TimeNS snapshotSize = T_Milis * 5000;
bool cutMissing = false;

std::vector<LOBPlotConfig> configs;

configs.emplace_back();
configs.back().fileName = "XCBT_MD_ZC_20150810_20150814.root";
configs.back().contract = "ZCZ5";
configs.back().yAxisTitle = "Price (dollar cents)";

std::vector<std::pair<TimeNS, std::string>> lines;

GenerateLiveLOBPlot(rootPath, outputFileName, beginTime, endTime, snapshotSize, configs, lines, cutMissing, 10);
// Out:
// ID: 60636
//  Progress:  100.0% |    16 sec running (37471464 rows)
// Number of messages: 25913, number of snapshots: 48, skip interval: 10, number of horizontal time bins: 2591, max vertical range: 125, max volume: 984
// Unique file: XCBT_MD_ZC_20150810_20150814.root
// ZCZ5=60636, low (ticks): 1457, high (ticks): 1582, low: 364.25000, high: 395.50000, tick size: 0.25000, messages: 25913, dollar value:0.00000
//  Progress:  100.0% |    14 sec running (37471464 rows)
// Window Plot: 49 horizontal bins required. (48)
// Message Plot: 25913 horizontal bins required. (2591)
// 1: Buy trades = 9538, Sell trades = 17197, Unmatched trades = 16460
// Error in <TDirectoryFile::Read>: Key not found
// Error in <TDirectoryFile::Read>: Key not found

// %%
std::string inputFileName = "file2.root";
std::string outputFileName = "Figure 3";

GeneralData generalData;
generalData.type = "time";
generalData.title = "Figure 3: December corn (ZCZ5) LOB behavior on an USDA announcement day using 5-second snapshots (August 12, 2015 from 10:58 AM to 11:02 AM CT)";
generalData.xAxisTitle = "Seconds since 10:58:00";
generalData.labelSize = 16;
generalData.titleSizeX = 20;
generalData.titleSizeY = 20;
generalData.legendSize = 20;

std::vector<PlotData> plotData;

plotData.emplace_back(0.5, "histWindowLob1");
plotData.back().isLOB = true;
plotData.back().drawAllLOBTicks = false;
plotData.back().drawLOBSpacers = false;
plotData.back().dataSpreadMaker = "spreadWindowMarker1";
plotData.emplace_back(0.3, "histWindowCumulTrade1");

drawLOB(inputFileName, outputFileName, generalData, plotData);
// Out:
// <div id="root_plot_1624804438365"
//      style="width: 1276px; height: 692px">
// </div>
// <script>
//
// function display_root_plot_1624804438365(Core) {
//    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":4000,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":4000,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":5e-5,"fXtoPixelk":5e-5,"fXtoPixel":1276,"fYtoAbsPixelk":692.00005,"fYtoPixelk":692.00005,"fYtoPixel":-692,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1276,"fVtoAbsPixelk":692.00005,"fVtoPixelk":692,"fVtoPixel":-692,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":7.83699059561128e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00144508670520231,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPad","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":4000,"fLeftMargin":0.1,"fRightMargin":0.12,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":4000,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-30.7692323563368,"fY1":-0.125000009313226,"fX2":276.923077452112,"fY2":1.12500000931323,"fXtoAbsPixelk":127.600055704165,"fXtoPixelk":127.600055704165,"fXtoPixel":4.14699997147918,"fYtoAbsPixelk":622.800045875358,"fYtoPixelk":622.800045875358,"fYtoPixel":-553.599991750717,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":1276,"fVtoAbsPixelk":692.00005,"fVtoPixelk":692,"fVtoPixel":-692,"fAbsPixeltoXk":-30.7692323563368,"fPixeltoXk":-30.7692323563368,"fPixeltoX":0.241138173831073,"fAbsPixeltoYk":1.12500000931323,"fPixeltoYk":-0.125000009313226,"fPixeltoY":-0.00180635840841973,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":240,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":4000,"fX1":0,"fY1":0,"fX2":240,"fY2":1,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":520,"fName":"background","fTitle":"Figure 3: December corn (ZCZ5) LOB behavior on an USDA announcement day using 5-second snapshots (August 12, 2015 from 10:58 AM to 11:02 AM CT)","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":1179,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":600,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":4096,"fName":"xaxis","fTitle":"Seconds since 10:58:00","fNdivisions":505,"fAxisColor":1,"fLabelColor":1,"fLabelFont":43,"fLabelOffset":0.005,"fLabelSize":12,"fTickLength":0.03,"fTitleOffset":1.5,"fTitleSize":18,"fTitleColor":1,"fTitleFont":43,"fNbins":48,"fXmin":0,"fXmax":240,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"","fNdivisions":505,"fAxi ...
