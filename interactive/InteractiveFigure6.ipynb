// %%
#include "../../highlo/scripts/LiveLOB/GenerateLiveLOBPlot.cxx"

// %%
#include "../../highlo/scripts/LiveLOB/drawLOB3.C"

// %%
%jsroot on

// %%
std::string rootPath = "root://eosproject//eos/project/h/highlo/CMEROOT/messages";
std::string outputFileName = "file4.root";
TimeNS beginTime = timestampToNS("2015""11""12""1500""00""000");
TimeNS endTime   = timestampToNS("2015""11""12""1505""00""000");
TimeNS snapshotSize = T_Milis * 5000;
bool cutMissing = false;

std::vector<LOBPlotConfig> configs;

configs.emplace_back();
configs.back().fileName = "CL/XNYM_MD_CL_20151109_20151113.root";
configs.back().contract = "CLZ5";
configs.back().yAxisTitle = "#splitline{CLZ5: Price}{(dollar cents)}";

configs.emplace_back();
configs.back().fileName = "NG/XNYM_MD_NG_20151109_20151113.root";
configs.back().contract = "NGZ5";
configs.back().yAxisTitle = "#splitline{NGZ5: Price}{(dollar cents)}";

std::vector<std::pair<TimeNS, std::string>> lines;

GenerateLiveLOBPlot(rootPath, outputFileName, beginTime, endTime, snapshotSize, configs, lines, cutMissing, 10);
// Out:
// Error in <TDirectoryFile::Read>: Key not found
// ID: 176502
// ID: 126515
//  Progress:  100.0% |   211 sec running (522364905 rows)                       memory |
// Number of messages: 72628, number of snapshots: 60, skip interval: 10, number of horizontal time bins: 7262, max vertical range: 50, max volume: 169
// Unique file: CL/XNYM_MD_CL_20151109_20151113.root
// Error in <TDirectoryFile::Read>: Key not found
// Unique file: NG/XNYM_MD_NG_20151109_20151113.root
// CLZ5=176502, low (ticks): 4216, high (ticks): 4266, low: 4216.00000, high: 4266.00000, tick size: 1.00000, messages: 59306, dollar value:0.00000
// NGZ5=126515, low (ticks): 2267, high (ticks): 2294, low: 2267.00000, high: 2294.00000, tick size: 1.00000, messages: 13322, dollar value:0.00000
//  Progress:  100.0% |   163 sec running (522364905 rows)                       memory |
// Window Plot: 61 horizontal bins required. (60)
// Message Plot: 72628 horizontal bins required. (7262)
// ...

// %%
std::string inputFileName = "file4.root";
std::string outputFileName = "Figure 6";

GeneralData generalData;
generalData.type = "mes";
generalData.type = "Figure 6: December Crude Oil (CLZ5) and December Henry Hub Natural Gas (NGZ5) LOB behavior (November 12, 2015 from 09:00 AM to 09:05 AM CT)";
generalData.xAxisTitle = "Messages since 09:00:00";
generalData.labelSize = 16;
generalData.titleSizeX = 20;
generalData.titleSizeY = 20;
generalData.legendSize = 20;

std::vector<PlotData> plotData;

plotData.emplace_back(0.4, "histMessageLob1");
plotData.back().isLOB = true;
plotData.back().drawAllLOBTicks = false;
plotData.back().drawLOBSpacers = false;
plotData.back().dataSpreadMaker = "spreadMessageMarker1";
plotData.emplace_back(0.4, "histMessageLob2");
plotData.back().isLOB = true;
plotData.back().drawAllLOBTicks = false;
plotData.back().drawLOBSpacers = false;
plotData.back().dataSpreadMaker = "spreadMessageMarker2";
plotData.emplace_back(0.4, "histMessageCumulTrade1");
plotData.back().legendLeft = "CLZ5";
plotData.back().dataLeft2 = "histMessageCumulTrade2";
plotData.back().legendLeft2 = "NGZ5";
plotData.emplace_back(0.4, "histMessageCumulTime"); 
plotData.back().yAxisTitle = "#splitline{Seconds since}{    09:00:00}";

drawLOB(inputFileName, outputFileName, generalData, plotData);
// Out:
// <div id="root_plot_1624804618266"
//      style="width: 1276px; height: 692px">
// </div>
// <script>
//
// function display_root_plot_1624804618266(Core) {
// ...
