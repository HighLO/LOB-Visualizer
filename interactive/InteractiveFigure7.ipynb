// %%
#include "../../highlo/scripts/LiveLOB/GenerateLiveLOBPlot.cxx"

// %%
#include "../../highlo/scripts/LiveLOB/drawLOB3.C"

// %%
%jsroot on

// %%
std::string rootPath = "root://eosproject//eos/project/h/highlo/CMEROOT/messages/ZW";
std::string outputFileName = "file5.root";
TimeNS beginTime = timestampToNS("2015""10""13""1400""00""000");
TimeNS endTime   = timestampToNS("2015""10""13""1410""00""000");
TimeNS snapshotSize = T_Milis * 1000;
bool cutMissing = false;

std::vector<LOBPlotConfig> configs;

configs.emplace_back();
configs.back().fileName = "XCBT_MD_ZW_20151012_20151016.root";
configs.back().contract = "ZWZ5";
configs.back().yAxisTitle = "Price (dollar cents)";

std::vector<std::pair<TimeNS, std::string>> lines;

GenerateLiveLOBPlot(rootPath, outputFileName, beginTime, endTime, snapshotSize, configs, lines, cutMissing);
// Out:
// ID: 255018
//  Progress:  100.0% |     6 sec running (15054542 rows)
// Number of messages: 12767, number of snapshots: 600, skip interval: 1, number of horizontal time bins: 12767, max vertical range: 26, max volume: 259
// Unique file: XCBT_MD_ZW_20151012_20151016.root
// ZWZ5=255018, low (ticks): 2046, high (ticks): 2072, low: 511.50000, high: 518.00000, tick size: 0.25000, messages: 12767, dollar value:0.00000
//  Progress:  100.0% |     6 sec running (15054542 rows)
// Window Plot: 601 horizontal bins required. (600)
// Message Plot: 12767 horizontal bins required. (12767)
// 1: Buy trades = 1530, Sell trades = 802, Unmatched trades = 80
// Error in <TDirectoryFile::Read>: Key not found
// Error in <TDirectoryFile::Read>: Key not found

// %%
std::string inputFileName = "file5.root";
std::string outputFileName = "Figure 7";

GeneralData generalData;
generalData.title = "Figure 7: December Chicago SRW Wheat (ZWZ5) LOB behavior (October 13, 2015 from 09:00 AM to 09:20 AM CT)";
generalData.type = "mes";
generalData.xAxisTitle = "Messages since 09:00:00";
generalData.labelSize = 16;
generalData.titleSizeX = 20;
generalData.titleSizeY = 20;
generalData.legendSize = 20;

std::vector<PlotData> plotData;

plotData.emplace_back(0.4, "histMessageLob1");
plotData.back().isLOB = true;
plotData.back().drawAllLOBTicks = false;
plotData.back().drawLOBSpacers = false;
plotData.back().dataSpreadMaker = "spreadMessageMarker1";
plotData.emplace_back(0.2, "histMessageCumulTrade1");
plotData.back().legendLeft = "Cumulative Trade Volume";
plotData.back().overlay = true;
plotData.back().dataRight = "histMessageBidVolume1";
plotData.back().titleRight = "Total Volume";
plotData.back().legendRight = "Bid Side Volume";
plotData.back().scaleRight = 0.25;
plotData.back().colorRight = kOrange;
plotData.back().dataRight2 = "histMessageAskVolume1";
plotData.back().legendRight2 = "Ask Side Volume";

plotData.emplace_back(0.2, "histMessageCumulTime"); 
plotData.back().yAxisTitle = "#splitline{Seconds since}{    09:00:00}";

drawLOB(inputFileName, outputFileName, generalData, plotData);
// Out:
// <div id="root_plot_1624804671024"
//      style="width: 1276px; height: 692px">
// </div>
// <script>
//
// function display_root_plot_1624804671024(Core) {
// ...
